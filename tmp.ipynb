# %%
import pandas as pd
import igraph
import numpy as np
import pdb
from ndex2.nice_cx_network import NiceCXNetwork
import ndex2.client as nc
import ndex2
import networkx as nx
from fa2 import ForceAtlas2
import networkx as nx
from networkx.drawing import nx_pydot as pyd

from py2cytoscape import cyrest
import json
import requests

# %%
nice_cx_network = ndex2.create_nice_cx_from_server(server='public.ndexbio.org', uuid='16beeb91-6e0a-11e9-848d-0ac135e8bacf')
nice_cx_network.to_cx()
# Out:
# Generating CX
# [{'numberVerification': [{'longNumber': 281474976710655}]},
#  {'metaData': [{'name': 'nodes',
#     'elementCount': 59,
#     'idCounter': 59,
#     'version': '1.0',
#     'consistencyGroup': 1,
#     'properties': []},
#    {'name': 'edges',
#     'elementCount': 51,
#     'idCounter': 51,
#     'version': '1.0',
#     'consistencyGroup': 1,
#     'properties': []},
#    {'name': 'networkAttributes',
#     'elementCount': 17,
#     'idCounter': 17,
#     'version': '1.0',
#     'consistencyGroup': 1,
#     'properties': []},
#    {'name': 'nodeAttributes',
#     'elementCount': 1062,
#     'idCounter': 1062,
#     'version': '1.0',
#     'consistencyGroup': 1,
#     'properties': []},
#    {'name': 'edgeAttributes',
#     'elementCount': 408,
#     'idCounter': 408,
#     'version': '1.0',
#     'consistencyGroup': 1,
#     'properties': []},
#    {'name': 'cyVisualProperties',
#     'elementCount': 113,
#     'idCounter': 114,
#     'properties': []},
# ...
